# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from matplotlib.pyplot import figure

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
df.index = pd.to_datetime(df.index)
df.head(2)
# Out:
#                 D_NO2    D_PM10K      N_NO2      N_O3    N_PM10K     O_NO2  \
# 2010-01-01  62.420425   48.68121  37.758297  4.000452  34.853405  52.36298
# 2010-01-02  49.886177  148.30754  25.938934  4.637932  45.783848  36.95639
#
#               O_PM10K     S_NO2      S_O3    S_PM10K  ...  Sud_Windspeed  \
# 2010-01-01  41.291916  45.16553  2.108327   58.87648  ...       0.358427
# 2010-01-02  76.422780  33.30085  1.795727  169.94360  ...       0.279739
#
#               West_RH  West_Temp  West_Winddirection  West_Windspeed  \
# 2010-01-01  83.031044   3.497470           189.95006        0.326422
# 2010-01-02  86.777100   3.033653           214.33745        0.206639
#
#             Ost_Pressure  Ost_RH  Ost_Temp  Ost_Winddirection  Ost_Windspeed
# 2010-01-01           NaN     NaN       NaN                NaN            NaN
# 2010-01-02           NaN     NaN       NaN                NaN            NaN
#
# [2 rows x 62 columns]

# %%
factors = ['N_NO2','N_PM10K']
years = ['2019','2020']

# %%
for factor in factors:
    for year in years:
        df_f = df[[factor]].loc[year]
        df_f['month'] = df_f.index.month
        df_f['day'] = df_f.index.day
        df_pivot = df_f.pivot(index='day', columns='month', values=factor)

        plt.figure(figsize=(8, 6), dpi=80)
        ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
        #plt.title(year+'\n'+factor, fontdict={'fontsize':15})
        plt.title(year+', '+factor, fontdict={'fontsize':15})
        plt.xlabel('Months', fontsize = 15) # x-axis label with fontsize 15
        plt.ylabel('Days', fontsize = 15) # y-axis label with fontsize 15
        #plt.yticks(rotation=90)

# %% [markdown]
# ## sve isto samo drugaciji title:

# %%
for factor in factors:
    for year in years:
        df_f = df[[factor]].loc[year]
        df_f['month'] = df_f.index.month
        df_f['day'] = df_f.index.day
        df_pivot = df_f.pivot(index='day', columns='month', values=factor)

        plt.figure(figsize=(8, 6), dpi=80)
        ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
        plt.title(year+'\n'+factor, fontdict={'fontsize':15})
        #plt.title(year+', '+factor, fontdict={'fontsize':15})
        plt.xlabel('Months', fontsize = 15) # x-axis label with fontsize 15
        plt.ylabel('Days', fontsize = 15) # y-axis label with fontsize 15
        #plt.yticks(rotation=90)

# %% [markdown]
# ## kao funkcija:

# %%
def heatmaps(factors, years):    
    for factor in factors:
        for year in years:
            df_f = df[[factor]].loc[year]
            df_f['month'] = df_f.index.month
            df_f['day'] = df_f.index.day
            df_pivot = df_f.pivot(index='day', columns='month', values=factor)

            plt.figure(figsize=(8, 6), dpi=80)
            ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
            plt.title(year+'\n'+factor, fontdict={'fontsize':15})
            #plt.title(year+', '+factor, fontdict={'fontsize':15})
            plt.xlabel('Months', fontsize = 15) # x-axis label with fontsize 15
            plt.ylabel('Days', fontsize = 15) # y-axis label with fontsize 15
            #plt.yticks(rotation=90)

# %%
heatmaps(factors, years)

# %%
def fun(i,j):
    df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
    df.index = pd.to_datetime(df.index)
    if i == '2019' and j == 'N_NO2':
        df=df[['N_NO2']].loc['2019-01-01':'2019-12-31']
        df.index.year
        df['month'] = df.index.month
        df['day'] = df.index.day
        df_pivot = df.pivot(index='day', columns='month', values='N_NO2') 
    elif i == '2020' and j == 'N_NO2':
        df=df[['N_NO2']].loc['2020-01-01':'2020-12-31']
        df.index.year
        df['month'] = df.index.month
        df['day'] = df.index.day
        df_pivot = df.pivot(index='day', columns='month', values='N_NO2')
    elif i == '2019' and j == 'N_PM10K':
        df=df[['N_PM10K']].loc['2019-01-01':'2019-12-31']
        df.index.year
        df['month'] = df.index.month
        df['day'] = df.index.day
        df_pivot = df.pivot(index='day', columns='month', values='N_PM10K')
    elif i == '2020' and j == 'N_PM10K':
        df=df[['N_PM10K']].loc['2020-01-01':'2020-12-31'] 
        df.index.year
        df['month'] = df.index.month
        df['day'] = df.index.day
        df_pivot = df.pivot(index='day', columns='month', values='N_PM10K')
    return df_pivot

# %%
i = input ('Year 2019 or 2020: ')
j = input ('Parameter N_NO2 or N_PM10K: ')
# Out:
# Year 2019 or 2020: 2020
# Parameter N_NO2 or N_PM10K: N_PM10K

# %% [markdown]
# * ### da ti se ovaj tekst dolje prije plota ne vidi, zadnja linija moze ici plt.show()<br>
# - samo komentar, na x osi su mjeseci, a na y dani, lako rjesivo :D

# %%
fun(i,j)

plt.figure(figsize=(8, 6), dpi=80)
ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")

plt.xlabel('Years', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Months', fontsize = 15) # y-axis label with fontsize 15
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5]),
#  [Text(0, 0.5, '1'),
#   Text(0, 1.5, '2'),
#   Text(0, 2.5, '3'),
#   Text(0, 3.5, '4'),
#   Text(0, 4.5, '5'),
#   Text(0, 5.5, '6'),
#   Text(0, 6.5, '7'),
#   Text(0, 7.5, '8'),
#   Text(0, 8.5, '9'),
#   Text(0, 9.5, '10'),
#   Text(0, 10.5, '11'),
#   Text(0, 11.5, '12'),
#   Text(0, 12.5, '13'),
#   Text(0, 13.5, '14'),
#   Text(0, 14.5, '15'),
#   Text(0, 15.5, '16'),
#   Text(0, 16.5, '17'),
#   Text(0, 17.5, '18'),
#   Text(0, 18.5, '19'),
#   Text(0, 19.5, '20'),
#   Text(0, 20.5, '21'),
#   Text(0, 21.5, '22'),
#   Text(0, 22.5, '23'),
#   Text(0, 23.5, '24'),
#   Text(0, 24.5, '25'),
#   Text(0, 25.5, '26'),
#   Text(0, 26.5, '27'),
#   Text(0, 27.5, '28'),
#   Text(0, 28.5, '29'),
#   Text(0, 29.5, '30'),
#   Text(0, 30.5, '31')])
