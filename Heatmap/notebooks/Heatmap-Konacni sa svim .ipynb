# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from matplotlib.pyplot import figure

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['D_NO2', 'D_PM10K', 'N_NO2', 'N_O3', 'N_PM10K', 'O_NO2', 'O_PM10K',
#        'S_NO2', 'S_O3', 'S_PM10K', 'W_NO2', 'W_PM10K', 'N_Ox', 'S_Ox', 'year',
#        'dayofyear', 'month_Apr', 'month_Aug', 'month_Dec', 'month_Feb',
#        'month_Jan', 'month_Jul', 'month_Jun', 'month_Mar', 'month_May',
#        'month_Nov', 'month_Oct', 'month_Sep', 'weekday_Friday',
#        'weekday_Monday', 'weekday_Saturday', 'weekday_Sunday',
#        'weekday_Thursday', 'weekday_Tuesday', 'weekday_Wednesday',
#        'season_fall', 'season_spring', 'season_summer', 'season_winter',
#        'holiday', 'holiday_school', 'DonBosco_RH', 'DonBosco_Temp',
#        'Nord_Precip', 'Nord_Pressure', 'Nord_RH', 'Nord_Temp',
#        'Nord_Winddirection', 'Nord_Windspeed', 'Sud_RH', 'Sud_Temp',
#        'Sud_Winddirection', 'Sud_Windspeed', 'West_RH', 'West_Temp',
#        'West_Winddirection', 'West_Windspeed', 'Ost_Pressure', 'Ost_RH',
#        'Ost_Temp', 'Ost_Winddirection', 'Ost_Windspeed'],
#       dtype='object')

# %% [markdown]
# # 2019 N_NO2

# %% [markdown]
# Ucitavanje podataka

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)

# %% [markdown]
# Prevodenje index-a u datum format

# %%
df.index = pd.to_datetime(df.index)

# %% [markdown]
# Izdvajanje podataka za 2019 godinu za N_NO2

# %%
df=df[['N_NO2']].loc['2019-01-01':'2019-12-31']

# %% [markdown]
# Izdvajanje godine, mjeseca i dana za 2019

# %%
df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %% [markdown]
# Spajanje svega u tablicu za graf

# %%
df_pivot = df.pivot(index='day', columns='month', values='N_NO2')

# %% [markdown]
# Izrada grafa

# %%
plt.figure(figsize=(8, 6), dpi=80)
ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
ax.set_title('2019', fontdict={'fontsize':20})
plt.xlabel('Years', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Months', fontsize = 15) # y-axis label with fontsize 15
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5]),
#  [Text(0, 0.5, '1'),
#   Text(0, 1.5, '2'),
#   Text(0, 2.5, '3'),
#   Text(0, 3.5, '4'),
#   Text(0, 4.5, '5'),
#   Text(0, 5.5, '6'),
#   Text(0, 6.5, '7'),
#   Text(0, 7.5, '8'),
#   Text(0, 8.5, '9'),
#   Text(0, 9.5, '10'),
#   Text(0, 10.5, '11'),
#   Text(0, 11.5, '12'),
#   Text(0, 12.5, '13'),
#   Text(0, 13.5, '14'),
#   Text(0, 14.5, '15'),
#   Text(0, 15.5, '16'),
#   Text(0, 16.5, '17'),
#   Text(0, 17.5, '18'),
#   Text(0, 18.5, '19'),
#   Text(0, 19.5, '20'),
#   Text(0, 20.5, '21'),
#   Text(0, 21.5, '22'),
#   Text(0, 22.5, '23'),
#   Text(0, 23.5, '24'),
#   Text(0, 24.5, '25'),
#   Text(0, 25.5, '26'),
#   Text(0, 26.5, '27'),
#   Text(0, 27.5, '28'),
#   Text(0, 28.5, '29'),
#   Text(0, 29.5, '30'),
#   Text(0, 30.5, '31')])

# %% [markdown]
# # 2020

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
df.index = pd.to_datetime(df.index)
df=df[['N_NO2']].loc['2020-01-01':'2020-12-31']
df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df_pivot = df.pivot(index='day', columns='month', values='N_NO2')
plt.figure(figsize=(8, 6), dpi=80)
ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
ax.set_title('2020', fontdict={'fontsize':20})
plt.xlabel('Years', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Months', fontsize = 15) # y-axis label with fontsize 15
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5]),
#  [Text(0, 0.5, '1'),
#   Text(0, 1.5, '2'),
#   Text(0, 2.5, '3'),
#   Text(0, 3.5, '4'),
#   Text(0, 4.5, '5'),
#   Text(0, 5.5, '6'),
#   Text(0, 6.5, '7'),
#   Text(0, 7.5, '8'),
#   Text(0, 8.5, '9'),
#   Text(0, 9.5, '10'),
#   Text(0, 10.5, '11'),
#   Text(0, 11.5, '12'),
#   Text(0, 12.5, '13'),
#   Text(0, 13.5, '14'),
#   Text(0, 14.5, '15'),
#   Text(0, 15.5, '16'),
#   Text(0, 16.5, '17'),
#   Text(0, 17.5, '18'),
#   Text(0, 18.5, '19'),
#   Text(0, 19.5, '20'),
#   Text(0, 20.5, '21'),
#   Text(0, 21.5, '22'),
#   Text(0, 22.5, '23'),
#   Text(0, 23.5, '24'),
#   Text(0, 24.5, '25'),
#   Text(0, 25.5, '26'),
#   Text(0, 26.5, '27'),
#   Text(0, 27.5, '28'),
#   Text(0, 28.5, '29'),
#   Text(0, 29.5, '30'),
#   Text(0, 30.5, '31')])

# %% [markdown]
# # 2019 N_PM10K

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
df.index = pd.to_datetime(df.index)
df=df[['N_PM10K']].loc['2019-01-01':'2019-12-31']
df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df_pivot = df.pivot(index='day', columns='month', values='N_PM10K')
plt.figure(figsize=(8, 6), dpi=80)
ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
ax.set_title('2019', fontdict={'fontsize':20})
plt.xlabel('Years', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Months', fontsize = 15) # y-axis label with fontsize 15
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5]),
#  [Text(0, 0.5, '1'),
#   Text(0, 1.5, '2'),
#   Text(0, 2.5, '3'),
#   Text(0, 3.5, '4'),
#   Text(0, 4.5, '5'),
#   Text(0, 5.5, '6'),
#   Text(0, 6.5, '7'),
#   Text(0, 7.5, '8'),
#   Text(0, 8.5, '9'),
#   Text(0, 9.5, '10'),
#   Text(0, 10.5, '11'),
#   Text(0, 11.5, '12'),
#   Text(0, 12.5, '13'),
#   Text(0, 13.5, '14'),
#   Text(0, 14.5, '15'),
#   Text(0, 15.5, '16'),
#   Text(0, 16.5, '17'),
#   Text(0, 17.5, '18'),
#   Text(0, 18.5, '19'),
#   Text(0, 19.5, '20'),
#   Text(0, 20.5, '21'),
#   Text(0, 21.5, '22'),
#   Text(0, 22.5, '23'),
#   Text(0, 23.5, '24'),
#   Text(0, 24.5, '25'),
#   Text(0, 25.5, '26'),
#   Text(0, 26.5, '27'),
#   Text(0, 27.5, '28'),
#   Text(0, 28.5, '29'),
#   Text(0, 29.5, '30'),
#   Text(0, 30.5, '31')])

# %% [markdown]
# # 2020 N_PM10K

# %%
df=pd.read_csv('..\Pollution Know center\\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
df.index = pd.to_datetime(df.index)
df=df[['N_PM10K']].loc['2020-01-01':'2020-12-31']
df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df_pivot = df.pivot(index='day', columns='month', values='N_PM10K')
plt.figure(figsize=(8, 6), dpi=80)
ax = sns.heatmap(df_pivot,linewidths=.5,cmap="YlGnBu")
ax.set_title('2020', fontdict={'fontsize':20})
plt.xlabel('Years', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Months', fontsize = 15) # y-axis label with fontsize 15
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5]),
#  [Text(0, 0.5, '1'),
#   Text(0, 1.5, '2'),
#   Text(0, 2.5, '3'),
#   Text(0, 3.5, '4'),
#   Text(0, 4.5, '5'),
#   Text(0, 5.5, '6'),
#   Text(0, 6.5, '7'),
#   Text(0, 7.5, '8'),
#   Text(0, 8.5, '9'),
#   Text(0, 9.5, '10'),
#   Text(0, 10.5, '11'),
#   Text(0, 11.5, '12'),
#   Text(0, 12.5, '13'),
#   Text(0, 13.5, '14'),
#   Text(0, 14.5, '15'),
#   Text(0, 15.5, '16'),
#   Text(0, 16.5, '17'),
#   Text(0, 17.5, '18'),
#   Text(0, 18.5, '19'),
#   Text(0, 19.5, '20'),
#   Text(0, 20.5, '21'),
#   Text(0, 21.5, '22'),
#   Text(0, 22.5, '23'),
#   Text(0, 23.5, '24'),
#   Text(0, 24.5, '25'),
#   Text(0, 25.5, '26'),
#   Text(0, 26.5, '27'),
#   Text(0, 27.5, '28'),
#   Text(0, 28.5, '29'),
#   Text(0, 29.5, '30'),
#   Text(0, 30.5, '31')])
