# %% [markdown]
# Import

# %%
# sys packages
import os,sys
sys.path.append('..')
from math import pi
# 3rd party packages
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import numpy as np
from windrose import WindroseAxes
from IPython.display import Image
from IPython.core.display import HTML
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import dateutil.parser
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# Podaci

# %%
df=pd.read_csv(r'..\data\5sta(DNOWS)_3com(NO2,PM10K,O3)_year2010_TemporalDummies_Ox_holidays_meteo.csv', index_col=0)
df.index = pd.to_datetime(df.index)

df_1 = df.dropna(axis = 0, how ='any')

# %%
N = ['Nord_Winddirection', 'Nord_Windspeed']

df_windrose = df_1[N]
df_windrose = df[N]['2018-01-01':'2020-03-15']

# %%
df_windrose
# Out:
#             Nord_Winddirection  Nord_Windspeed
# 2018-01-01           188.78535        0.525265
# 2018-01-02           242.04047        0.521665
# 2018-01-03           223.70158        0.327764
# 2018-01-04           222.11096        0.364699
# 2018-01-05           247.34747        0.270665
# ...                        ...             ...
# 2020-03-11           228.43272        0.807125
# 2020-03-12           216.54237        0.621644
# 2020-03-13           203.12128        0.916752
# 2020-03-14           214.34221        0.695497
# 2020-03-15           182.27693        0.700455
#
# [805 rows x 2 columns]

# %%
ax = WindroseAxes.from_ax()
ax.bar(df_windrose.Nord_Winddirection, df_windrose.Nord_Windspeed,opening=.9,edgecolor='white')
ax.set_title('N od 01-01-2018 do 03-15-2020')
ax.legend(bbox_to_anchor=(1.0, 1.0),fontsize=16)
ax.set_xticklabels(['N', 'NW',  'W', 'SW', 'S', 'SE','E', 'NE'])
ax.set_theta_zero_location('N')
plt.rc('font', family='Times New Roman', weight='bold', size=20)

# %%
S = ['Sud_Winddirection', 'Sud_Windspeed']
df_windrose = df_1[S]
df_windrose = df[S]['2018-01-01':'2020-03-15']

# %%
ax = WindroseAxes.from_ax()
ax.bar(df_windrose.Sud_Winddirection, df_windrose.Sud_Windspeed,opening=.9,edgecolor='white')
ax.set_title('S')
ax.legend(bbox_to_anchor=(1.0, 1.0),fontsize=16)
ax.set_xticklabels(['N', 'NW',  'W', 'SW', 'S', 'SE','E', 'NE'])
ax.set_theta_zero_location('N')
plt.rc('font', family='Times New Roman', weight='bold', size=20)

# %%
S = ['Sud_Winddirection', 'Sud_Windspeed']
df_windrose = df_1[S]
df_windrose = df[S].loc['2019']

# %%
W = ['West_Winddirection', 'West_Windspeed']
df_windrose = df_1[W]
df_windrose = df[W]['2018-01-01':'2020-03-15']

# %%
ax = WindroseAxes.from_ax()
ax.bar(df_windrose.West_Winddirection, df_windrose.West_Windspeed,opening=.9,edgecolor='white')
ax.set_title('W')
ax.legend(bbox_to_anchor=(1.0, 1.0),fontsize=16)
ax.set_xticklabels(['N', 'NW',  'W', 'SW', 'S', 'SE','E', 'NE'])
ax.set_theta_zero_location('N')
plt.rc('font', family='Times New Roman', weight='bold', size=20)

# %%
O = ['Ost_Winddirection', 'Ost_Windspeed']
df_windrose = df_1[O]
df_windrose = df[O].loc['2018-01-01':'2020-03-15']
ax = WindroseAxes.from_ax()
ax.bar(df_windrose.Ost_Winddirection, df_windrose.Ost_Windspeed,opening=.9,edgecolor='white')
ax.set_title('O')
ax.legend(bbox_to_anchor=(1.0, 1.0),fontsize=16)
ax.set_xticklabels(['N', 'NW',  'W', 'SW', 'S', 'SE','E', 'NE'])
ax.set_theta_zero_location('N')
plt.rc('font', family='Times New Roman', weight='bold', size=20)
